# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("previsao_de_renda.csv")

df
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %%
# Analisando a renda em relação à posse de imóvel
ax = sns.pointplot(x="posse_de_imovel", y="renda",
                  data=df, dodge=True, ci=95)
plt.grid()

# %% [markdown]
# Verifica-se que a renda média dos clientes que possuem imóvel (pouco acima de 4700) é superior à renda dos que não têm (aproximadamente 4450), uma vez que até o ponto inferior da barra de erros da média dos que têm imóvel (por volta de 4630) é maior do que o ponto superior da barra de erros dos que não tem (em torno de 4550). Dessa forma, essa variável é uma boa preditora em relação à renda do cliente.

# %%
# Analisando a renda em relação à posse de veículo
ax = sns.pointplot(x="posse_de_veiculo", y="renda",
                  data=df, dodge=True, ci=95, color="red")
plt.grid()

# %% [markdown]
# A renda média dos cliente que não possuem veículo está em torno de 5000, sendo que o ponto inferior da barra de erros está por volta de 4900); por outro lado, a renda média dos clientes que não possuem veículo é, aproximadamente, 4400, com o ponto superior da barra de erros estando próximo a 4500. Com isso, pode-se dizer que esta variável é uma boa preditora da renda do cliente, sendo melhor do que a posse de imóvel.

# %%
# Analisando a renda em relação à ambas as posses
ax = sns.pointplot(x="posse_de_imovel", y="renda",
                   hue="posse_de_veiculo", data=df, 
                   dodge=True, ci=95)
plt.grid()

# %% [markdown]
# Os clientes que possuem imóvel e veículo apresentam uma renda média similar ao dos que possuem veículo mas que não possuem imóvel, de forma que não seja possível diferenciar a renda dos que possuem ambos os fatores dos que possuem apenas veículo. Por outro lado, os que possuem imóvel mas não têm veículo apresentam renda média levemente superior aos que não apresentam qualquer dos objetos. A grande discrepância das rendas médias está entre os clientes que possuem ambos em relação aos que não apresentam qualquer um deles, sendo esta questão (ter ambos ou nenhum) uma boa preditora da renda do cliente.
